# %% [markdown]
# <a href="https://colab.research.google.com/github/abhixcode/deeplearning/blob/main/DL_CW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import imageio
import matplotlib.pyplot as plt
import numpy as np


img = imageio.imread('butterfly_GT.bmp') #, as_gray=True, pilmode='YCbCr').astype(np.float32)
#print(img.shape)
plt.imshow(img)
plt.show()

img2 = imageio.imread('butterfly_GT.bmp', as_gray=True).astype(np.float32)
plt.imshow(img2)
plt.show()
